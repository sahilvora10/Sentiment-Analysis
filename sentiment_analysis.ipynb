# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sahilvora10/Sentiment-Analysis/blob/master/sentiment_analysis.ipynb)

# %% [markdown]
# **SENTIMENT ANALYSIS**

# %% [markdown]
# **Curating a Dataset**

# %%
def print_data(i):
  print(labels[i] + "\t \t \t" + reviews[i][:80] + "....")

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-4b424355-0d10-4547-b91a-64d3b6b952b2" name="files[]" multiple disabled />
#      <output id="result-4b424355-0d10-4547-b91a-64d3b6b952b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving reviews.txt to reviews.txt
# User uploaded file "reviews.txt" with length 33678267 bytes

# %%
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-fedaf75a-b9bb-4b8e-99e9-623d8e45c097" name="files[]" multiple disabled />
#      <output id="result-fedaf75a-b9bb-4b8e-99e9-623d8e45c097">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels.txt to labels.txt
# User uploaded file "labels.txt" with length 249998 bytes

# %%
g = open('reviews.txt','r') #input read file
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

# %%
len(reviews)
# Out:
# 25000

# %%
g = open('labels.txt','r') # input labels
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %%
len(labels)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0:5]
# Out:
# ['POSITIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE']

# %% [markdown]
# **QUICK THEORY VALIDATION**

# %%
from collections import Counter
import numpy as np

# %%
pos_c = Counter()
neg_c = Counter()
tot_c = Counter()

# %%
for i in range(len(labels)):
  words = reviews[i].split(" ")
  if(labels[i] == 'POSITIVE'):
    for j in words:
      pos_c[j] += 1
      tot_c[j] += 1
  elif(labels[i] == 'NEGATIVE'):
    for j in words:
      neg_c[j] += 1
      tot_c[j] += 1

# %%
pos_c.most_common()
# Out:
# [('', 550468),
#  ('the', 173324),
#  ('.', 159654),
#  ('and', 89722),
#  ('a', 83688),
#  ('of', 76855),
#  ('to', 66746),
#  ('is', 57245),
#  ('in', 50215),
#  ('br', 49235),
#  ('it', 48025),
#  ('i', 40743),
#  ('that', 35630),
#  ('this', 35080),
#  ('s', 33815),
#  ('as', 26308),
#  ('with', 23247),
#  ('for', 22416),
#  ('was', 21917),
#  ('film', 20937),
#  ('but', 20822),
#  ('movie', 19074),
#  ('his', 17227),
#  ('on', 17008),
#  ('you', 16681),
#  ('he', 16282),
#  ('are', 14807),
#  ('not', 14272),
#  ('t', 13720),
#  ('one', 13655),
#  ('have', 12587),
#  ('be', 12416),
#  ('by', 11997),
#  ('all', 11942),
#  ('who', 11464),
#  ('an', 11294),
#  ('at', 11234),
#  ('from', 10767),
#  ('her', 10474),
#  ('they', 9895),
#  ('has', 9186),
#  ('so', 9154),
#  ('like', 9038),
#  ('about', 8313),
#  ('very', 8305),
#  ('out', 8134),
#  ('there', 8057),
#  ('she', 7779),
#  ('what', 7737),
#  ('or', 7732),
#  ('good', 7720),
#  ('more', 7521),
#  ('when', 7456),
# ...

# %%
neg_c.most_common()
# Out:
# [('', 561438),
#  ('.', 167532),
#  ('the', 163386),
#  ('a', 79315),
#  ('and', 74381),
#  ('of', 69004),
#  ('to', 68972),
#  ('br', 52635),
#  ('is', 50080),
#  ('it', 48323),
#  ('i', 46878),
#  ('in', 43752),
#  ('this', 40915),
#  ('that', 37614),
#  ('s', 31544),
#  ('was', 26289),
#  ('movie', 24965),
#  ('for', 21927),
#  ('but', 21781),
#  ('with', 20878),
#  ('as', 20623),
#  ('t', 20359),
#  ('film', 19217),
#  ('you', 17547),
#  ('on', 17192),
#  ('not', 16352),
#  ('have', 15143),
#  ('are', 14623),
#  ('be', 14541),
#  ('he', 13856),
#  ('one', 13133),
#  ('they', 13011),
#  ('at', 12277),
#  ('his', 12147),
#  ('all', 12035),
#  ('so', 11462),
#  ('like', 11236),
#  ('there', 10772),
#  ('just', 10619),
#  ('by', 10549),
#  ('or', 10270),
#  ('an', 10265),
#  ('who', 9969),
#  ('from', 9731),
#  ('if', 9516),
#  ('about', 9061),
#  ('out', 8979),
#  ('what', 8422),
#  ('some', 8305),
#  ('no', 8143),
#  ('her', 7947),
#  ('even', 7687),
#  ('can', 7653),
# ...

# %%
pos_neg_ratios = Counter()
for t,c in list(tot_c.most_common()):
  if(c>100):
    ratio = pos_c[t] / float(neg_c[t]+1)
    pos_neg_ratios[t]= ratio

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0608187921927694
# Pos-to-neg ratio for 'amazing' = 4.022813688212928
# Pos-to-neg ratio for 'terrible' = 0.17744252873563218

# %%
for w,r in pos_neg_ratios.most_common():
  pos_neg_ratios[w]=np.log(r)

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05904105540639773
# Pos-to-neg ratio for 'amazing' = 1.3919815802404802
# Pos-to-neg ratio for 'terrible' = -1.7291085042663878

# %%
pos_neg_ratios.most_common() #list common words in positive review
# Out:
# [('edie', 4.6913478822291435),
#  ('paulie', 4.07753744390572),
#  ('felix', 3.152736022363656),
#  ('polanski', 2.8233610476132043),
#  ('matthau', 2.80672172860924),
#  ('victoria', 2.681021528714291),
#  ('mildred', 2.6026896854443837),
#  ('gandhi', 2.538973871058276),
#  ('flawless', 2.451005098112319),
#  ('superbly', 2.26002547857525),
#  ('perfection', 2.159484249353372),
#  ('astaire', 2.1400661634962708),
#  ('captures', 2.038619547159581),
#  ('voight', 2.030170492673053),
#  ('wonderfully', 2.0218960560332353),
#  ('powell', 1.978345424808467),
#  ('brosnan', 1.9547990964725592),
#  ('lily', 1.9203768470501485),
#  ('bakshi', 1.9029851043382795),
#  ('lincoln', 1.9014583864844796),
#  ('refreshing', 1.8551812956655511),
#  ('breathtaking', 1.8481124057791867),
#  ('bourne', 1.8478489358790986),
#  ('lemmon', 1.8458266904983307),
#  ('delightful', 1.8002701588959635),
#  ('flynn', 1.7996646487351682),
#  ('andrews', 1.7764919970972666),
#  ('homer', 1.7692866133759964),
# ...

# %%
list(reversed(pos_neg_ratios.most_common()))[0:30]  #negative review,top 30
# Out:
# [('boll', -4.969813299576001),
#  ('uwe', -4.624972813284271),
#  ('seagal', -3.644143560272545),
#  ('unwatchable', -3.258096538021482),
#  ('stinker', -3.2088254890146994),
#  ('mst', -2.9502698994772336),
#  ('incoherent', -2.9368917735310576),
#  ('unfunny', -2.6922395950755678),
#  ('waste', -2.6186484579840514),
#  ('blah', -2.5704288232261625),
#  ('horrid', -2.4849066497880004),
#  ('pointless', -2.4553061800117097),
#  ('atrocious', -2.4259083090260445),
#  ('redeeming', -2.3682390632154826),
#  ('prom', -2.3608540011180215),
#  ('drivel', -2.3470368555648795),
#  ('lousy', -2.307572634505085),
#  ('worst', -2.286987896180378),
#  ('laughable', -2.264363880173848),
#  ('awful', -2.227194247027435),
#  ('poorly', -2.2207550747464135),
#  ('wasting', -2.204604684633842),
#  ('remotely', -2.1972245773362196),
#  ('existent', -2.0794415416798357),
#  ('boredom', -1.995100393246085),
#  ('miserably', -1.9924301646902063),
#  ('sucks', -1.987068221548821),
# ...

# %% [markdown]
# **CREATING INPUT/OUTPUT DATA**

# %%
vocab = set(tot_c.keys())

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %%
layer_0 = np.zeros((1,vocab_size))
layer_0.shape
# Out:
# (1, 74074)

# %%
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'dang': 1,
#  'rodent': 2,
#  'moggies': 3,
#  'jowls': 4,
#  'harking': 5,
#  'pastparticularly': 6,
#  'dormant': 7,
#  'ventured': 8,
#  'palermo': 9,
#  'rosalyn': 10,
#  'legionairres': 11,
#  'haunts': 12,
#  'zuzz': 13,
#  'overburdened': 14,
#  'timeslip': 15,
#  'carradine': 16,
#  'waldau': 17,
#  'sbardellati': 18,
#  'shaadi': 19,
#  'booming': 20,
#  'freemasons': 21,
#  'impossibilities': 22,
#  'lara': 23,
#  'haply': 24,
#  'mongolian': 25,
#  'amjad': 26,
#  'shibasaki': 27,
#  'leech': 28,
#  'mamas': 29,
#  'secured': 30,
#  'hearth': 31,
#  'valor': 32,
#  'heavenly': 33,
#  'pinkus': 34,
#  'namaste': 35,
#  'fifteen': 36,
#  'groped': 37,
#  'millers': 38,
#  'profligate': 39,
#  'genderbender': 40,
#  'choo': 41,
#  'bhumika': 42,
#  'cathrine': 43,
#  'christenson': 44,
#  'sector': 45,
#  'ched': 46,
#  'methamphetamine': 47,
#  'disruptions': 48,
#  'grownups': 49,
#  'steph': 50,
#  'crystal': 51,
#  'contemplative': 52,
#  'rahad': 53,
# ...

# %%
def update_input_layer(review):
  global layer_0
  layer_0 *= 0
  words = review.split(" ")
  for j in words:
    layer_0[0][word2index[j]]+=1

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[18.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
def get_target_for_label(label):
  if(label == 'POSITIVE'):
    return 1
  else:
    return 0

# %%
labels[0]
get_target_for_label(labels[0])
# Out:
# 1

# %%
labels[1]
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# **BUILD A NEURAL NETWORK**

# %%
import time
import sys
import numpy as np

# %%
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
      np.random.seed(1)
      self.pre_process_data(reviews, labels)
      self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
      
      
    def pre_process_data(self, reviews, labels):
          
          review_vocab = set()
          for review in reviews:
            for word in review.split(" "):
              review_vocab.add(word)
          
          self.review_vocab = list(review_vocab)
      
          label_vocab = set()
          for label in labels:
            label_vocab.add(label)
          
          self.label_vocab = list(label_vocab)
          
          self.review_vocab_size = len(self.review_vocab)
          self.label_vocab_size = len(self.label_vocab)
          
          self.word2index = {}
          for i,word in enumerate(self.review_vocab):
            self.word2index[word] = i
          
          self.label2index = {}
          for i,label in enumerate(self.label_vocab):
            self.label2index[word] = i
            
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
          
          self.input_nodes = input_nodes
          self.hidden_nodes = hidden_nodes
          self.output_nodes = output_nodes
          self.learning_rate = learning_rate
          
          self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
          self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5,(self.hidden_nodes,self.output_nodes))
          self.layer_0 = np.zeros((1,input_nodes))
         
    def update_input_layer(self,review):
        self.layer_0 *= 0
        for word in review.split(" "):
            # NOTE: This if-check was not in the version of this method created in Project 2,
            #       and it appears in Andrew's Project 3 solution without explanation. 
            #       It simply ensures the word is actually a key in word2index before
            #       accessing it, which is important because accessing an invalid key
            #       with raise an exception in Python. This allows us to ignore unknown
            #       words encountered in new reviews.
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
          
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
          return 1
        else:
          return 0
        
    def sigmoid(self,x):
        o= 1/(1+ np.exp(-x))
        return o
      
    def sigmoid_output_2_derivative(self,output):
        a = (1-output)*(output)
        return a
      
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correctso = 0
        
        # Remember when we started for printing time statistics
        start = time.time()
        
        for i in range(len(training_labels)):
          review=training_reviews[i]
          label= training_labels[i]
          
          
          
          self.update_input_layer(review)
          layer_1 = self.layer_0.dot(self.weights_0_1)
          layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
          
          #backward
          err_2= layer_2 - self.get_target_for_label(label)
          del_2= (err_2*self.sigmoid_output_2_derivative(layer_2))
          err_1= del_2.dot(self.weights_1_2.T)
          del_1= err_1
          
          #update
          self.weights_1_2 -= layer_1.T.dot(del_2)*self.learning_rate
          self.weights_0_1 -= self.layer_0.T.dot(del_1) * self.learning_rate
          
          if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correctso += 1
          elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correctso += 1
            
                          
          elapsed_time = float(time.time() - start)
          reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
          
          sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correctso) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correctso * 100 / float(i+1))[:4] + "%")
          if(i % 2500 == 0):
                print("")
          
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
            
    def run(self, review):
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):573.0 #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):203.0 #Correct:1251 #Trained:2501 Training Accuracy:50.0%
# Progress:20.8% Speed(reviews/sec):199.6 #Correct:2501 #Trained:5001 Training Accuracy:50.0%
# Progress:31.2% Speed(reviews/sec):202.5 #Correct:3751 #Trained:7501 Training Accuracy:50.0%
# Progress:41.6% Speed(reviews/sec):204.9 #Correct:5001 #Trained:10001 Training Accuracy:50.0%
# Progress:48.9% Speed(reviews/sec):203.9 #Correct:5879 #Trained:11757 Training Accuracy:50.0%
# Progress:52.0% Speed(reviews/sec):203.7 #Correct:6251 #Trained:12501 Training Accuracy:50.0%
# Progress:62.5% Speed(reviews/sec):203.9 #Correct:7501 #Trained:15001 Training Accuracy:50.0%
# Progress:72.9% Speed(reviews/sec):204.7 #Correct:8751 #Trained:17501 Training Accuracy:50.0%
# Progress:83.3% Speed(reviews/sec):205.4 #Correct:10001 #Trained:20001 Training Accuracy:50.0%
# ...

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):208.7 #Correct:1271 #Trained:2501 Training Accuracy:50.8%
# Progress:20.8% Speed(reviews/sec):206.9 #Correct:2526 #Trained:5001 Training Accuracy:50.5%
# Progress:31.2% Speed(reviews/sec):205.3 #Correct:3767 #Trained:7501 Training Accuracy:50.2%
# Progress:41.6% Speed(reviews/sec):206.0 #Correct:5002 #Trained:10001 Training Accuracy:50.0%
# Progress:49.1% Speed(reviews/sec):205.4 #Correct:5894 #Trained:11795 Training Accuracy:49.9%
# Progress:52.0% Speed(reviews/sec):205.3 #Correct:6244 #Trained:12501 Training Accuracy:49.9%
# Progress:62.5% Speed(reviews/sec):204.6 #Correct:7475 #Trained:15001 Training Accuracy:49.8%
# Progress:72.9% Speed(reviews/sec):204.7 #Correct:8697 #Trained:17501 Training Accuracy:49.6%
# Progress:83.3% Speed(reviews/sec):204.7 #Correct:9935 #Trained:20001 Training Accuracy:49.6%
# ...

# %% [markdown]
# The problem here lies in the data, while preproscessing the data contains useless inputs which is hampering the neural network,therefore that NOISE need to be reduced.

# %% [markdown]
# **REDUCING NOISE**

# %%
update_input_layer(reviews[0])

# %%
layer_0   #so here a word is having 18 occurance but that word id  a empty space so we need to reduce it.
# Out:
# array([[18.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
#so here we can see there are useless words going in neural net. we need to reduce it.
review_counter = Counter()
for word in reviews[0].split(" "):
    review_counter[word] += 1

review_counter.most_common()
# Out:
# [('.', 27),
#  ('', 18),
#  ('the', 9),
#  ('to', 6),
#  ('high', 5),
#  ('i', 5),
#  ('bromwell', 4),
#  ('is', 4),
#  ('a', 4),
#  ('teachers', 4),
#  ('that', 4),
#  ('of', 4),
#  ('it', 2),
#  ('at', 2),
#  ('as', 2),
#  ('school', 2),
#  ('my', 2),
#  ('in', 2),
#  ('me', 2),
#  ('students', 2),
#  ('their', 2),
#  ('student', 2),
#  ('cartoon', 1),
#  ('comedy', 1),
#  ('ran', 1),
#  ('same', 1),
#  ('time', 1),
#  ('some', 1),
#  ('other', 1),
#  ('programs', 1),
#  ('about', 1),
#  ('life', 1),
#  ('such', 1),
#  ('years', 1),
#  ('teaching', 1),
#  ('profession', 1),
#  ('lead', 1),
#  ('believe', 1),
#  ('s', 1),
#  ('satire', 1),
#  ('much', 1),
#  ('closer', 1),
#  ('reality', 1),
#  ('than', 1),
#  ('scramble', 1),
#  ('survive', 1),
#  ('financially', 1),
#  ('insightful', 1),
#  ('who', 1),
#  ('can', 1),
#  ('see', 1),
#  ('right', 1),
#  ('through', 1),
#  ('pathetic', 1),
#  ('pomp', 1),
#  ('pettiness', 1),
#  ('whole', 1),
#  ('situation', 1),
#  ('all', 1),
# ...

# %%
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
      np.random.seed(1)
      self.pre_process_data(reviews, labels)
      self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
      
      
    def pre_process_data(self, reviews, labels):
          
          review_vocab = set()
          for review in reviews:
            for word in review.split(" "):
              review_vocab.add(word)
          
          self.review_vocab = list(review_vocab)
      
          label_vocab = set()
          for label in labels:
            label_vocab.add(label)
          
          self.label_vocab = list(label_vocab)
          
          self.review_vocab_size = len(self.review_vocab)
          self.label_vocab_size = len(self.label_vocab)
          
          self.word2index = {}
          for i,word in enumerate(self.review_vocab):
            self.word2index[word] = i
          
          self.label2index = {}
          for i,label in enumerate(self.label_vocab):
            self.label2index[word] = i
            
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
          
          self.input_nodes = input_nodes
          self.hidden_nodes = hidden_nodes
          self.output_nodes = output_nodes
          self.learning_rate = learning_rate
          
          self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
          self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5,(self.hidden_nodes,self.output_nodes))
          self.layer_0 = np.zeros((1,input_nodes))
         
    def update_input_layer(self,review):
        self.layer_0 *= 0
        for word in review.split(" "):
           
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] = 1  #we just not the occurance number but rather just stores whether or not a word was used.
          
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
          return 1
        else:
          return 0
        
    def sigmoid(self,x):
        o= 1/(1+ np.exp(-x))
        return o
      
    def sigmoid_output_2_derivative(self,output):
        a = (1-output)*(output)
        return a
      
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correctso = 0
        
        # Remember when we started for printing time statistics
        start = time.time()
        
        for i in range(len(training_labels)):
          review=training_reviews[i]
          label= training_labels[i]
          
          
          
          self.update_input_layer(review)
          layer_1 = self.layer_0.dot(self.weights_0_1)
          layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
          
          #backward
          err_2= layer_2 - self.get_target_for_label(label)
          del_2= (err_2*self.sigmoid_output_2_derivative(layer_2))
          err_1= del_2.dot(self.weights_1_2.T)
          del_1= err_1
          
          #update
          self.weights_1_2 -= layer_1.T.dot(del_2)*self.learning_rate
          self.weights_0_1 -= self.layer_0.T.dot(del_1) * self.learning_rate
          
          if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correctso += 1
          elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correctso += 1
            
                          
          elapsed_time = float(time.time() - start)
          reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
          
          sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correctso) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correctso * 100 / float(i+1))[:4] + "%")
          if(i % 2500 == 0):
                print("")
          
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
            
    def run(self, review):
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):197.4 #Correct:1773 #Trained:2501 Training Accuracy:70.8%
# Progress:20.8% Speed(reviews/sec):198.0 #Correct:3757 #Trained:5001 Training Accuracy:75.1%
# Progress:31.2% Speed(reviews/sec):202.3 #Correct:5843 #Trained:7501 Training Accuracy:77.8%
# Progress:41.6% Speed(reviews/sec):203.5 #Correct:7983 #Trained:10001 Training Accuracy:79.8%
# Progress:49.0% Speed(reviews/sec):203.2 #Correct:9475 #Trained:11773 Training Accuracy:80.4%
# Progress:52.0% Speed(reviews/sec):202.8 #Correct:10101 #Trained:12501 Training Accuracy:80.8%
# Progress:62.5% Speed(reviews/sec):203.2 #Correct:12239 #Trained:15001 Training Accuracy:81.5%
# Progress:72.9% Speed(reviews/sec):204.3 #Correct:14345 #Trained:17501 Training Accuracy:81.9%
# Progress:83.3% Speed(reviews/sec):204.3 #Correct:16524 #Trained:20001 Training Accuracy:82.6%
# ...

# %% [markdown]
# And we clearly get a better result just by changing a bit of code in update layer.

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):723.5 #Correct:854 #Tested:1000 Testing Accuracy:85.4%

# %% [markdown]
# and this is clearly a dramatic change and increase from 50%

# %% [markdown]
# **Making our Network More Efficient**

# %%
import time
import sys
import numpy as np


class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        
        
        np.random.seed(1)

        
        self.pre_process_data(reviews, labels)
        
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        
        self.review_vocab = list(review_vocab)
        
        
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
       
        self.label_vocab = list(label_vocab)
        
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
       
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
       
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
       
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

       
        self.learning_rate = learning_rate

       

       
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))

       
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
       
       
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    
    
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    
    def train(self, training_reviews_raw, training_labels):

     
        training_reviews = list()
        for review in training_reviews_raw:
            ind = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    ind.add(self.word2index[word])
            training_reviews.append(list(ind))

        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        
        for i in range(len(training_reviews)):
            
           
            review = training_reviews[i]
            label = training_labels[i]
            
           
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]

           
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            
            
           

            #backward
            err_2 = layer_2 - self.get_target_for_label(label) 
            del_2 = err_2* self.sigmoid_output_2_derivative(layer_2)
            err_1 = del_2.dot(self.weights_1_2.T) 
            del_1 = err_1 


            
            
            
            #update
            self.weights_1_2 -= self.layer_1.T.dot(del_2) * self.learning_rate 
            
            
            for index in review:
                self.weights_0_1[index] -= del_1[0] * self.learning_rate 

            
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            
            
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        
        self.layer_1 *= 0
        indi = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                indi.add(self.word2index[word])
        for index in indi:
            self.layer_1 += self.weights_0_1[index]
        
        
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):1162. #Correct:1809 #Trained:2501 Training Accuracy:72.3%
# Progress:20.8% Speed(reviews/sec):1141. #Correct:3779 #Trained:5001 Training Accuracy:75.5%
# Progress:31.2% Speed(reviews/sec):1142. #Correct:5884 #Trained:7501 Training Accuracy:78.4%
# Progress:41.6% Speed(reviews/sec):1145. #Correct:8013 #Trained:10001 Training Accuracy:80.1%
# Progress:52.0% Speed(reviews/sec):1143. #Correct:10137 #Trained:12501 Training Accuracy:81.0%
# Progress:62.5% Speed(reviews/sec):1143. #Correct:12264 #Trained:15001 Training Accuracy:81.7%
# Progress:72.9% Speed(reviews/sec):1141. #Correct:14367 #Trained:17501 Training Accuracy:82.0%
# Progress:83.3% Speed(reviews/sec):1138. #Correct:16542 #Trained:20001 Training Accuracy:82.7%
# Progress:93.7% Speed(reviews/sec):1135. #Correct:18726 #Trained:22501 Training Accuracy:83.2%
# ...

# %% [markdown]
# the speed of reviews per second improved a lot

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):1997. #Correct:850 #Tested:1000 Testing Accuracy:85.0%

# %% [markdown]
# **Further Noise Reduction**

# %%
import time
import sys
import numpy as np


class SentimentNetwork:
    def __init__(self, reviews,labels,min_count = 10,polarity_cutoff = 0.1,hidden_nodes = 10, learning_rate = 0.1):
        
        
        np.random.seed(1)

        
        self.pre_process_data(reviews, labels,min_count,polarity_cutoff)
        
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels,min_count ,polarity_cutoff):
      
        pos_c = Counter()
        neg_c = Counter()
        tot_c = Counter()

        for i in range(len(reviews)):
            if(labels[i] == 'POSITIVE'):
                for word in reviews[i].split(" "):
                    pos_c[word] += 1
                    tot_c[word] += 1
            else:
                for word in reviews[i].split(" "):
                    neg_c[word] += 1
                    tot_c[word] += 1

        pos_neg_ratios = Counter()

        for t,c in list(tot_c.most_common()):
            if(c >= 50):
                ratio = pos_c[t] / float(neg_c[t]+1)
                pos_neg_ratios[t] = ratio

        for w,r in pos_neg_ratios.most_common():
            if(r > 1):
                pos_neg_ratios[word] = np.log(r)
            else:
                pos_neg_ratios[word] = -np.log((1 / (r + 0.01)))
        
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                
                if(tot_c[word] > min_count):
                    if(word in pos_neg_ratios.keys()):
                        if((pos_neg_ratios[word] >= polarity_cutoff) or (pos_neg_ratios[word] <= -polarity_cutoff)):
                            review_vocab.add(word)
                    else:
                        review_vocab.add(word)

        
        self.review_vocab = list(review_vocab)
        
        
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
       
        self.label_vocab = list(label_vocab)
        
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
       
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
       
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
       
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

       
        self.learning_rate = learning_rate

       

       
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))

       
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
       
       
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    
    
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    
    def train(self, training_reviews_raw, training_labels):

     
        training_reviews = list()
        for review in training_reviews_raw:
            ind = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    ind.add(self.word2index[word])
            training_reviews.append(list(ind))

        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        
        for i in range(len(training_reviews)):
            
           
            review = training_reviews[i]
            label = training_labels[i]
            
           
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]

           
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            
            
           

            #backward
            err_2 = layer_2 - self.get_target_for_label(label) 
            del_2 = err_2* self.sigmoid_output_2_derivative(layer_2)
            err_1 = del_2.dot(self.weights_1_2.T) 
            del_1 = err_1 


            
            
            
            #update
            self.weights_1_2 -= self.layer_1.T.dot(del_2) * self.learning_rate 
            
            
            for index in review:
                self.weights_0_1[index] -= del_1[0] * self.learning_rate 

            
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            
            
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        
        self.layer_1 *= 0
        indi = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                indi.add(self.word2index[word])
        for index in indi:
            self.layer_1 += self.weights_0_1[index]
        
        
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):1213. #Correct:1954 #Trained:2501 Training Accuracy:78.1%
# Progress:20.8% Speed(reviews/sec):1189. #Correct:4000 #Trained:5001 Training Accuracy:79.9%
# Progress:31.2% Speed(reviews/sec):1183. #Correct:6116 #Trained:7501 Training Accuracy:81.5%
# Progress:41.6% Speed(reviews/sec):1185. #Correct:8266 #Trained:10001 Training Accuracy:82.6%
# Progress:52.0% Speed(reviews/sec):1182. #Correct:10425 #Trained:12501 Training Accuracy:83.3%
# Progress:62.5% Speed(reviews/sec):1182. #Correct:12557 #Trained:15001 Training Accuracy:83.7%
# Progress:72.9% Speed(reviews/sec):1179. #Correct:14657 #Trained:17501 Training Accuracy:83.7%
# Progress:83.3% Speed(reviews/sec):1177. #Correct:16818 #Trained:20001 Training Accuracy:84.0%
# Progress:93.7% Speed(reviews/sec):1174. #Correct:18991 #Trained:22501 Training Accuracy:84.4%
# ...

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):2007. #Correct:858 #Tested:1000 Testing Accuracy:85.8%

# %% [markdown]
# **Knowing about Weights**

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)
mlp_full.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):1117. #Correct:1962 #Trained:2501 Training Accuracy:78.4%
# Progress:20.8% Speed(reviews/sec):1099. #Correct:4002 #Trained:5001 Training Accuracy:80.0%
# Progress:31.2% Speed(reviews/sec):1094. #Correct:6120 #Trained:7501 Training Accuracy:81.5%
# Progress:41.6% Speed(reviews/sec):1101. #Correct:8271 #Trained:10001 Training Accuracy:82.7%
# Progress:52.0% Speed(reviews/sec):1099. #Correct:10431 #Trained:12501 Training Accuracy:83.4%
# Progress:62.5% Speed(reviews/sec):1098. #Correct:12565 #Trained:15001 Training Accuracy:83.7%
# Progress:72.9% Speed(reviews/sec):1096. #Correct:14670 #Trained:17501 Training Accuracy:83.8%
# Progress:83.3% Speed(reviews/sec):1093. #Correct:16833 #Trained:20001 Training Accuracy:84.1%
# Progress:93.7% Speed(reviews/sec):1091. #Correct:19015 #Trained:22501 Training Accuracy:84.5%
# ...

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")
# Out:
# [('excellent', 0.13672950757352462),
#  ('perfect', 0.1254828608722594),
#  ('amazing', 0.09182763392599966),
#  ('today', 0.09022366269441419),
#  ('wonderful', 0.08935597696221458),
#  ('fun', 0.08750446667420687),
#  ('great', 0.08714175888229198),
#  ('best', 0.08581088561788057),
#  ('liked', 0.07769762912384341),
#  ('definitely', 0.076628781406966),
#  ('brilliant', 0.07342385876927901),
#  ('loved', 0.07328542892812212),
#  ('favorite', 0.07278113603616072),
#  ('superb', 0.07173620717850504),
#  ('fantastic', 0.07092219191626617),
#  ('job', 0.06916061720763404),
#  ('incredible', 0.0664240779526144),
#  ('enjoyable', 0.06563256050288875),
#  ('rare', 0.06481921266261505),
#  ('highly', 0.06388945335097049),
#  ('enjoyed', 0.062127546101812904),
#  ('wonderfully', 0.06205517860409014),
#  ('perfectly', 0.06109320881188736),
#  ('fascinating', 0.06066354793749385),
#  ('bit', 0.05965542704565304),
#  ('gem', 0.05951085929615676),
#  ('outstanding', 0.05886080814708299),
# ...

# %%
get_most_similar_words("terrible")
# Out:
# [('worst', 0.1696610725904985),
#  ('awful', 0.12026847019691245),
#  ('waste', 0.11945367265311002),
#  ('poor', 0.0927588875744355),
#  ('terrible', 0.09142538719772797),
#  ('dull', 0.08420927167822362),
#  ('poorly', 0.08124154451604204),
#  ('disappointment', 0.08006475962136873),
#  ('fails', 0.07859977372333751),
#  ('disappointing', 0.07733948548032338),
#  ('boring', 0.07712785874801288),
#  ('unfortunately', 0.07550244970585908),
#  ('worse', 0.07060183536419466),
#  ('mess', 0.07056429962359041),
#  ('stupid', 0.06948482283254305),
#  ('badly', 0.06688890366622857),
#  ('annoying', 0.0656870219033742),
#  ('bad', 0.06309381453757217),
#  ('save', 0.06288059749586573),
#  ('disappointed', 0.06269235381207287),
#  ('wasted', 0.06138718302805129),
#  ('supposed', 0.06098545295772515),
#  ('horrible', 0.06012177233938013),
#  ('laughable', 0.058698406285467644),
#  ('crap', 0.05810452866788458),
#  ('basically', 0.057218840369636176),
#  ('nothing', 0.0571582200430342),
# ...

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-175-1d2faddc4785> in <module>()
#       2 p = figure(tools="pan,wheel_zoom,reset,save",
#       3            toolbar_location="above",
# ----> 4            title="vector T-SNE for most polarized words")
#       5
#       6 source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     537                                         frameon=frameon,
#     538                                         FigureClass=FigureClass,
# --> 539                                         **kwargs)
#     540
#     541         if figLabel:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
# ...
